# %% [markdown]
# Nick Project - Grocery analysis

# %%
import pandas as pd

# Creating data dictionary
data = {
    'product_id': ['APU0000704111', 'APU0000711211', 'APU0000702111', 'APU0000706111', 'APU0000717311', 'APU0000708111',
                    'APU0000701111', 'APU0000709112', 'APU0000711311', 'APU0000701312', 'APU0000712311', 'APU000072610', 'APU000072511', 'APU00007471A', 'APU000074714'],
    'product_name': ['Bacon', 'Bananas', 'Bread', 'Chicken', 'Coffee', 'Eggs', 'Flour', 'Milk', 'Oranges', 'Rice',
                      'Tomatoes', 'Electricity per KWH', 'Fuel oil #2', 'Gasoline All Types', 'Unleaded Gasoline']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('product_mapping.csv', index=False)
